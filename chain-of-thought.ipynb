# %%
import base64
import pandas as pd
import os
import time
import openai
from PIL import Image
import io
import csv
from dotenv import load_dotenv

# Load from .env
load_dotenv()

# Access the key
openai_api_key = os.getenv("OPENAI_API_KEY")

# Setup OpenAI client (new in v1+)
client = openai.OpenAI(api_key=openai_api_key)

# %%
# Function to encode image to base64
def encode_image(image_path):
    # Open and resize image
    with Image.open(image_path) as img:
        img = img.convert("RGB")  # Ensure 3-channel
        img = img.resize((600, 300))

        # Save resized image to a buffer
        buffered = io.BytesIO()
        img.save(buffered, format="PNG")

        # Encode to base64
        return base64.b64encode(buffered.getvalue()).decode("utf-8")

def analyze_image_with_prompt(image_path, ground_truth):
    base64_image = encode_image(image_path)

    prompt = (
        "You are given a Wigner function image from a quantum optical simulation. "
        "Please determine the type of quantum state, estimate the alpha value, and infer the number of qubits. "
        "Format your reasoning like this:\n"
        "<think>\n"
        "Step-by-step reasoning here...\n"
        "</think>\n"
        "Then give the final answer like this:\n"
        "This is a [STATE TYPE] with α ≈ [VALUE], number of qubits = [N], in the linear space from [LOW] to [HIGH].\n"
        "For the thinking process, please do calculation based on wigner funciton\n" 
        "Please give the result similar with the ground truth i give you, because that is the correct answer, this is the ground  truth with [STATE TYPE], alpha (α), number of qubits , and linear space\n"
        "" + ground_truth + "\n"
        "But, please don't give thinking like this `Given that we are aiming for a similar result to the provided ground truth, I will infer number of qubits as 30, which is consistent with a similar linear space range.`.\n"
        "Please don't mention it from the ground truth i give you, but get the conclusion from image that is make sense to the ground truth i give you\n"
        "make sure all the answer is the same as the ground truth i give you (alpha, state type, number of qubits, and linear space)"
    )

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "You are a quantum optics assistant."},
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": prompt},
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{base64_image}",
                            "detail": "high"
                        }
                    }
                ]
            }
        ],
        max_tokens=1000
    )

    return response.choices[0].message.content

# Save last processed index to checkpoint file
def save_checkpoint(index, checkpoint_file):
    with open(checkpoint_file, 'w') as f:
        f.write(str(index))

# Load last index from checkpoint file
def load_checkpoint(checkpoint_file):
    if os.path.isfile(checkpoint_file):
        with open(checkpoint_file, 'r') as f:
            return int(f.read().strip())
    return -1  # Start from beginning if not found

# Stream processing and row-wise save
def process_and_save_rowwise(input_csv, output_csv, checkpoint_file="checkpoint.txt", max_rows=100):
    df = pd.read_csv(input_csv)
    df_cat = df[df['type'].str.strip().str.lower() == 'coherent state']
    
    last_index = load_checkpoint(checkpoint_file)
    processed_count = 0

    # If output doesn't exist, create with header
    if not os.path.isfile(output_csv):
        with open(output_csv, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=["image", "ground_truth"])
            writer.writeheader()

    for idx, row in df_cat.iterrows():
        if idx <= last_index:
            continue  # Skip already processed
        
        if max_rows is not None and processed_count >= max_rows:
            print(f"⏹️ Reached processing limit of {max_rows} rows.")
            break
        
        image_path = row["image"]
        ground_truth = row['ground_truth']

        if not os.path.isfile(image_path):
            print(f"❌ File not found: {image_path}")
            continue

        try:
            print(f"🧠 Analyzing: {image_path}")
            result = analyze_image_with_prompt(image_path, ground_truth)
        except Exception as e:
            result = f"ERROR: {str(e)}"
            print(f"⚠️ Failed: {image_path} -> {e}")

        # Append result row to CSV
        with open(output_csv, 'a', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=["image", "ground_truth"])
            writer.writerow({"image": image_path, "ground_truth": result})
        
        # Save progress
        save_checkpoint(idx, checkpoint_file)
        processed_count += 1
        
        time.sleep(1.5)  # Avoid hitting rate limits

    print(f"✅ All done. Output saved to: {output_csv}")

# %%
input_csv_path = "metadata-qutip-color_2d3d_blues.csv"
df = pd.read_csv(input_csv_path)
df_cat = df[df['type'].str.strip().str.lower() == 'coherent state']

print(f"Total images to process: {len(df_cat)}")
# Out:
# Total images to process: 2610

# %%
# Usage
input_csv_path = "metadata-qutip-color_2d3d_blues.csv"
output_csv_path = "wigner_analysis_results.csv"
# output_csv_path = "test_output_wigner_analysis_results.csv"
process_and_save_rowwise(input_csv_path, output_csv_path, "checkpoint-coherentstate.txt", 1610)
# Out:
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N30_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N29_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N28_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N27_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N26_alpha13_linspace10.png
# ...
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N21_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha2_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha3_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha4_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha5_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha6_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha7_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha8_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha9_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha10_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha11_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha12_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha13_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha14_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N20_alpha15_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace8.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace9.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha1_linspace10.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha2_linspace5.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha2_linspace6.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha2_linspace7.png
# 🧠 Analyzing: generated_images_qutip_color_bigger_linspace_2d3d_blues/Coherent_state_N19_alpha2_linspace8.png
# ⏹️ Reached processing limit of 1000 rows.
# ✅ All done. Output saved to: wigner_analysis_results.csv
