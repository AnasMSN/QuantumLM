# %%
import json
from pprint import pprint
from torchmetrics.text.bert import BERTScore
from torchmetrics.text import BLEUScore, CharErrorRate, MatchErrorRate, WordErrorRate

# Step 1: Load predictions and targets from JSON file
with open("extracted_base.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# # Optional: remove <think> tags if desired
# def clean(text):
#     return text.replace("<think>", "").replace("</think>", "").strip()

# preds = [clean(d['generated']) for d in data]
# target = [clean(d['ground_truth']) for d in data]
preds = [d['generated'] for d in data]
target = [d['ground_truth'] for d in data]

# Step 2: Compute metrics
print("=== Custom Model Evaluation ===")

bertscore = BERTScore(truncation=True)
bert_score = bertscore(preds, target)

# Extract and compute mean of F1, precision, and recall
avg_f1 = bert_score['f1'].mean().item()
avg_precision = bert_score['precision'].mean().item()
avg_recall = bert_score['recall'].mean().item()

# Print detailed scores
print("All BERTScore F1:", bert_score['f1'])
print(f"Mean F1 Score: {avg_f1:.4f}")
print(f"Mean Precision: {avg_precision:.4f}")
print(f"Mean Recall: {avg_recall:.4f}")

bleu1 = BLEUScore(n_gram=1)
# print blue1 score
print("BLEU1 score: ", bleu1(preds, target))

bleu2 = BLEUScore(n_gram=2)
# print blue2 score
print("BLEU2 score: ", bleu2(preds, target))


cer = CharErrorRate()
print("CER score: ", cer(preds, target))

mer = MatchErrorRate()
print("MER score: ", mer(preds, target))

wer = WordErrorRate()
print("WER score: ", wer(preds, target))
# Out:
# === Custom Model Evaluation ===
# /home/cqilab/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The argument `model_name_or_path` was not specified while it is required when the default `transformers` model is used. It will use the default recommended model - 'roberta-large'.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# 2025-05-02 10:38:07.293195: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-02 10:38:07.304171: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746149887.316727  321378 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746149887.320318  321378 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746149887.329647  321378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746149887.329657  321378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746149887.329658  321378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746149887.329660  321378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-02 10:38:07.332836: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      20 print("=== Custom Model Evaluation ===")
#      22 bertscore = BERTScore(truncation=True)
# ---> 23 all_pred_score = bertscore(preds, target)
#      24 # print all pred score and the mean of all pred score
#      25 print("All pred score: ", all_pred_score)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/metric.py:316, in Metric.forward(self, *args, **kwargs)
#     314     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     315 else:
# --> 316     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     318 return self._forward_cache
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/metric.py:386, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     384 # calculate batch state and compute batch value
#     385 self.update(*args, **kwargs)
# --> 386 batch_val = self.compute()
#     388 # reduce batch and global state
#     389 self._update_count = _update_count + 1
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/metric.py:700, in Metric._wrap_compute.<locals>.wrapped_func(*args, **kwargs)
#     692 # compute relies on the sync context manager to gather the states across processes and apply reduction
#     693 # if synchronization happened, the current rank accumulated states will be restored to keep
#     694 # accumulation going if ``should_unsync=True``,
#     695 with self.sync_context(
#     696     dist_sync_fn=self.dist_sync_fn,
#     697     should_sync=self._to_sync,
#     698     should_unsync=self._should_unsync,
#     699 ):
# --> 700     value = _squeeze_if_scalar(compute(*args, **kwargs))
#     701     # clone tensor to avoid in-place operations after compute, altering already computed results
#     702     value = apply_to_collection(value, Tensor, lambda x: x.clone())
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/text/bert.py:245, in BERTScore.compute(self)
#     237 preds = {
#     238     "input_ids": dim_zero_cat(self.preds_input_ids),
#     239     "attention_mask": dim_zero_cat(self.preds_attention_mask),
#     240 }
#     241 target = {
#     242     "input_ids": dim_zero_cat(self.target_input_ids),
#     243     "attention_mask": dim_zero_cat(self.target_attention_mask),
#     244 }
# --> 245 return bert_score(
#     246     preds=preds,
#     247     target=target,
#     248     model_name_or_path=self.model_name_or_path,
#     249     num_layers=self.num_layers,
#     250     all_layers=self.all_layers,
#     251     model=self.model,
#     252     user_tokenizer=self.tokenizer if self.user_tokenizer else None,
#     253     user_forward_fn=self.user_forward_fn,
#     254     verbose=self.verbose,
#     255     idf=self.idf,
#     256     device=self.embedding_device,
#     257     max_length=self.max_length,
#     258     batch_size=self.batch_size,
#     259     num_threads=self.num_threads,
#     260     return_hash=self.return_hash,
#     261     lang=self.lang,
#     262     rescale_with_baseline=self.rescale_with_baseline,
#     263     baseline_path=self.baseline_path,
#     264     baseline_url=self.baseline_url,
#     265 )
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/functional/text/bert.py:441, in bert_score(preds, target, model_name_or_path, num_layers, all_layers, model, user_tokenizer, user_forward_fn, verbose, idf, device, max_length, batch_size, num_threads, return_hash, lang, rescale_with_baseline, baseline_path, baseline_url, truncation)
#     438 target_loader = DataLoader(target_dataset, batch_size=batch_size, num_workers=num_threads)
#     439 preds_loader = DataLoader(preds_dataset, batch_size=batch_size, num_workers=num_threads)
# --> 441 target_embeddings, target_idf_scale = _get_embeddings_and_idf_scale(
#     442     target_loader, target_dataset.max_length, model, device, num_layers, all_layers, idf, verbose, user_forward_fn
#     443 )
#     444 preds_embeddings, preds_idf_scale = _get_embeddings_and_idf_scale(
#     445     preds_loader, preds_dataset.max_length, model, device, num_layers, all_layers, idf, verbose, user_forward_fn
#     446 )
#     448 preds_embeddings = preds_embeddings[preds_loader.dataset.sorting_indices]
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torchmetrics/functional/text/bert.py:117, in _get_embeddings_and_idf_scale(dataloader, target_len, model, device, num_layers, all_layers, idf, verbose, user_forward_fn)
#     115 if not all_layers:
#     116     if not user_forward_fn:
# --> 117         out = model(batch["input_ids"], batch["attention_mask"], output_hidden_states=True)
#     118         out = out.hidden_states[num_layers if num_layers is not None else -1]
#     119     else:
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:976, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     969 # Prepare head mask if needed
#     970 # 1.0 in head_mask indicate we keep the head
#     971 # attention_probs has shape bsz x n_heads x N x N
#     972 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     973 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     974 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 976 encoder_outputs = self.encoder(
#     977     embedding_output,
#     978     attention_mask=extended_attention_mask,
#     979     head_mask=head_mask,
#     980     encoder_hidden_states=encoder_hidden_states,
#     981     encoder_attention_mask=encoder_extended_attention_mask,
#     982     past_key_values=past_key_values,
#     983     use_cache=use_cache,
#     984     output_attentions=output_attentions,
#     985     output_hidden_states=output_hidden_states,
#     986     return_dict=return_dict,
#     987 )
#     988 sequence_output = encoder_outputs[0]
#     989 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:631, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     620     layer_outputs = self._gradient_checkpointing_func(
#     621         layer_module.__call__,
#     622         hidden_states,
#    (...)
#     628         output_attentions,
#     629     )
#     630 else:
# --> 631     layer_outputs = layer_module(
#     632         hidden_states,
#     633         attention_mask,
#     634         layer_head_mask,
#     635         encoder_hidden_states,
#     636         encoder_attention_mask,
#     637         past_key_value,
#     638         output_attentions,
#     639     )
#     641 hidden_states = layer_outputs[0]
#     642 if use_cache:
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:520, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     508 def forward(
#     509     self,
#     510     hidden_states: torch.Tensor,
#    (...)
#     517 ) -> Tuple[torch.Tensor]:
#     518     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     519     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 520     self_attention_outputs = self.attention(
#     521         hidden_states,
#     522         attention_mask,
#     523         head_mask,
#     524         output_attentions=output_attentions,
#     525         past_key_value=self_attn_past_key_value,
#     526     )
#     527     attention_output = self_attention_outputs[0]
#     529     # if decoder, the last output is tuple of self-attn cache
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:447, in RobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     437 def forward(
#     438     self,
#     439     hidden_states: torch.Tensor,
#    (...)
#     445     output_attentions: Optional[bool] = False,
#     446 ) -> Tuple[torch.Tensor]:
# --> 447     self_outputs = self.self(
#     448         hidden_states,
#     449         attention_mask,
#     450         head_mask,
#     451         encoder_hidden_states,
#     452         encoder_attention_mask,
#     453         past_key_value,
#     454         output_attentions,
#     455     )
#     456     attention_output = self.output(self_outputs[0], hidden_states)
#     457     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llmfinetune/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# KeyboardInterrupt:
